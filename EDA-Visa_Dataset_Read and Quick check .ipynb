# %%
# EDA
# we required some packages
#-----------------------------Data frame analysis-----------------------
# Pandas ======= dataframe  analysis

#--------------------------Numerical analysis-------------------------------
# numpy =======  numerical python ====== number analysis


#------------------------- ploting-----------------------------------------
# matplotlib ( mat-plot-library) ====== to plot any diagrams
# seaborn ======= to plot diagrams
# bokhe ======== plot diagrams

# plot the diagrams------- data visulaization (power bi/ tableau)



# ML

# sikitlearn ===> sklearn


# pandas
# numpy
# matplotlib
# seaborn
# sklearn

# --------------image analytics(DL)----------------------
# tensorflow(Deep learning) ==== > google
# opencv (we need to install)
# keras

# -------------text analytics(NLP)---------------------
# NLTK (natural language tool kit)
# scipy 


# BERT Transformers(ML+DL+NLP) Hugging Face
# transformers

# ChatGPT model (ML+DL+NLP)
# LLM

# %% [markdown]
# $Step-1$
#
# **Import packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# $Step-2$
#
# **Read the data**

# %%
# file location
# file name
# extenstion

# <file_location>//<file_name>.<extension>

# visa datasets

# .csv(comma sepearted value)  ,   .txt , .xlsx(excel)

C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Datafiles
    
Visadataset

.csv

"C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Datafiles\\Visadataset.csv"

# %%
file_name="C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Datafiles\\Visadataset.csv"
pd.read_csv(file_name)

#pd.read_csv("C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Datafiles\\Visadataset.csv")
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file_name="C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Datafiles\\bank.csv"
pd.read_csv(file_name,sep=';')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
# while reading the file
# take care of many things
# file path, headers,sep

# %%
file_name="C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Datafiles\\Visadataset.csv"
visa_dataset=pd.read_csv(file_name)

# %%
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
type(visa_dataset)

# string list dic set tupl  int float bool complex

# place your dataset where python code is there
#file_name="Visadataset.csv"
#visa_dataset=pd.read_csv(file_name)
# Out:
# pandas.core.frame.DataFrame

# %%
visa_dataset.shape

# 25480 = number of rows
# 12 = columns
# Out:
# (25480, 12)

# %%
type(visa_dataset.shape)
# Out:
# tuple

# %%
# number of rows are 25480
# number of columns are 12
a=(25480, 12)
a[0],a[1]
# Out:
# (25480, 12)

# %%
print("number of rows are:",visa_dataset.shape[0])
print("number of columns are:",visa_dataset.shape[1])
# Out:
# number of rows are: 25480
# number of columns are: 12

# %%
len(visa_dataset)
# Out:
# 25480

# %%
visa_dataset.size
# Out:
# 305760

# %%
25480*12 # total values
# Out:
# 305760

# %%
visa_dataset.columns # provide all the column names
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
dir(visa_dataset)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
- type

- len

- size

- shape

- columns

# %%
visa_dataset.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_dataset.tail(3)  # last 5 rows
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25477                South        146298.85         Year                  N
# 25478                 West         86154.77         Year                  Y
# 25479              Midwest         70876.91         Year                  Y
#
#       case_status
# 25477   Certified
# 25478   Certified
# 25479   Certified

# %%
visa_dataset.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %%
visa_dataset.take([0,1,2])  # default axis=0

# axis=0   rows
# axis=1   columns
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa_dataset.take([0,1,2],axis=1)

# axis=0   rows
# axis=1   columns
# Out:
#          case_id continent education_of_employee
# 0         EZYV01      Asia           High School
# 1         EZYV02      Asia              Master's
# 2         EZYV03      Asia            Bachelor's
# 3         EZYV04      Asia            Bachelor's
# 4         EZYV05    Africa              Master's
# ...          ...       ...                   ...
# 25475  EZYV25476      Asia            Bachelor's
# 25476  EZYV25477      Asia           High School
# 25477  EZYV25478      Asia              Master's
# 25478  EZYV25479      Asia              Master's
# 25479  EZYV25480      Asia            Bachelor's
#
# [25480 rows x 3 columns]

# %%
- head

- tail

- take

# %%
visa_dataset.take([100,200,300])  # default axis=0

# what is the axis : default =0 ======= > rows
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_dataset.take([100,200,300],axis=1) 

# what is the axis :1 ======= > columns
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [33], line 1
# ----> 1 visa_dataset.take([100,200,300],axis=1)
#       3 # what is the axis :1 ======= > columns
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3871, in NDFrame.take(self, indices, axis, is_copy, **kwargs)
#    3862     warnings.warn(
#    3863         "is_copy is deprecated and will be removed in a future version. "
#    3864         "'take' always returns a copy, so there is no need to specify this.",
#    3865         FutureWarning,
#    3866         stacklevel=find_stack_level(),
#    3867     )
#    3869 nv.validate_take((), kwargs)
# -> 3871 return self._take(indices, axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3886, in NDFrame._take(self, indices, axis, convert_indices)
#    3879 """
# ...

# %%
visa_dataset.head()   # top 5 rows
visa_dataset.tail()   # last 5 rows

# by using index operatio I want read the data : take
# list of index 
visa_dataset.take([0,1,2])

# [0,1,2] ======= represents rows or columns?
# based on axis 
# axis=0 ======== > rows
# axis=1 ========= > columns

# %%
visa_dataset.take([0,1,2])
# axis we did not mentioned : default=0 ====> rows
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa_dataset.take([0,1,2],axis=1)

# axis=1  : columns  0  1  2
# Out:
#          case_id continent education_of_employee
# 0         EZYV01      Asia           High School
# 1         EZYV02      Asia              Master's
# 2         EZYV03      Asia            Bachelor's
# 3         EZYV04      Asia            Bachelor's
# 4         EZYV05    Africa              Master's
# ...          ...       ...                   ...
# 25475  EZYV25476      Asia            Bachelor's
# 25476  EZYV25477      Asia           High School
# 25477  EZYV25478      Asia              Master's
# 25478  EZYV25479      Asia              Master's
# 25479  EZYV25480      Asia            Bachelor's
#
# [25480 rows x 3 columns]

# %%
# I want  150 250 350 rows  from 5,8,12 columns
# where we are missing

visa_dataset.take([5,8,11],axis=1).take([150,250,350])
# Out:
#      no_of_employees  prevailing_wage case_status
# 150            50351         529.1105      Denied
# 250             4280       61147.0700   Certified
# 350             1894      106937.8400      Denied

# %%
d1=visa_dataset.take([5,8,11],axis=1)
d1.take([150,250,350])
# Out:
#      no_of_employees  prevailing_wage case_status
# 150            50351         529.1105      Denied
# 250             4280       61147.0700   Certified
# 350             1894      106937.8400      Denied

# %% [markdown]
# - type
#
# - len
#
# - size
#
# - shape
#
# - columns
#
# - head
#
# - tail
#
# - take
